# %% [markdown]
# # PANDAS
# - THIS IS THE PYTHON LIBRARY.
# - THAT USED FOR DATA CLEANING , DATA MANIPULATION AND DATA ANALYSIS.

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '3.0.2'

# %%
# datafram => rows and columns  ke through banta h, basically table

# %%
# 1
# press shift + tab in
df = pd.DataFrame([11,22,33], columns= ['Col_name'])
print(df)
# Out:
#    Col_name
# 0        11
# 1        22
# 2        33

# %%
print(type(df))
# Out:
# <class 'pandas.DataFrame'>

# %%
data = {
    'Name': ['Madhav', 'Vishakha', 'Lalita', 'Rishabh'],
    'Age' : [16 , 17,18,19],
    'Salary': [90000, 70000 , 50000 , 30000]   
}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#        Name  Age  Salary
# 0    Madhav   16   90000
# 1  Vishakha   17   70000
# 2    Lalita   18   50000
# 3   Rishabh   19   30000

# %%
# 2
df.tail(2) # head = top 5 rows , tail = bottom rows
# Out:
#       Name  Age  Salary
# 2   Lalita   18   50000
# 3  Rishabh   19   30000

# %%
df.shape
# Out:
# (4, 3)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Salary'], dtype='str')

# %%
df.rename(columns = {'Salary' : 'Monthly_Salary'} , inplace = True) # inplace matlab ki dataframe mein bhi change kar do

# %%
df
# Out:
#        Name  Age  Monthly_Salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000
# 2    Lalita   18           50000
# 3   Rishabh   19           30000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            4 non-null      str
#  1   Age             4 non-null      int64
#  2   Monthly_Salary  4 non-null      int64
# dtypes: int64(2), str(1)
# memory usage: 228.0 bytes

# %%
df.describe() # show statistical summary for numerical columm , mean , standard deviation
# Out:
#              Age  Monthly_Salary
# count   4.000000        4.000000
# mean   17.500000    60000.000000
# std     1.290994    25819.888975
# min    16.000000    30000.000000
# 25%    16.750000    45000.000000
# 50%    17.500000    60000.000000
# 75%    18.250000    75000.000000
# max    19.000000    90000.000000

# %%
# 3. Save and load data from csv

# %%
df.to_csv('Test_data.csv' ,index = False) # not need index , 0 , 1 ,2

# %%
load_csv = pd.read_csv('Test_data.csv')

# %%
load_csv
# Out:
#        Name  Age  Monthly_Salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000
# 2    Lalita   18           50000
# 3   Rishabh   19           30000

# %%
# 4. Rows and Columns = Selection

# %%
# select column
# df[['Name']]
df[['Name', 'Monthly_Salary']]
# Out:
#        Name  Monthly_Salary
# 0    Madhav           90000
# 1  Vishakha           70000
# 2    Lalita           50000
# 3   Rishabh           30000

# %%
df[['Name']]
# Out:
#        Name
# 0    Madhav
# 1  Vishakha
# 2    Lalita
# 3   Rishabh

# %%
# select rows 2 methods
df.loc[df.Name == 'Madhav']
df.loc[(df.Name=='Madhav') & (df.Monthly_Salary>=5000)]
# label based indexing , search based indexing
# Out:
#      Name  Age  Monthly_Salary
# 0  Madhav   16           90000

# %%
df.loc[0:2] # include 2 value # label based indexing
# Out:
#        Name  Age  Monthly_Salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000
# 2    Lalita   18           50000

# %%
# iloc - index-value based
df.iloc[0]
df.iloc[0:2] # not include 2 value. [start : stop : step]
# Out:
#        Name  Age  Monthly_Salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000

# %%
# 5. filter dataframe

# %%
df
# Out:
#        Name  Age  Monthly_Salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000
# 2    Lalita   18           50000
# 3   Rishabh   19           30000

# %%
df_age_filter = df[df['Age'] >= 18]

# %%
df_age_filter
# Out:
#       Name  Age  Monthly_Salary
# 2   Lalita   18           50000
# 3  Rishabh   19           30000

# %%
df[(df['Age'] >= 18) & (df['Monthly_Salary'] >= 50000)]
# Out:
#      Name  Age  Monthly_Salary
# 2  Lalita   18           50000

# %%
df_age_filter.to_csv('age_filter.csv' , index = False)

# %%
df.where(df['Age'] >= 18)
# Out:
#       Name   Age  Monthly_Salary
# 0      NaN   NaN             NaN
# 1      NaN   NaN             NaN
# 2   Lalita  18.0         50000.0
# 3  Rishabh  19.0         30000.0

# %%
df.where((df['Age'] >= 18) & (df['Monthly_Salary'] >= 40000), other = "Not Eligible") # use this to filter
# Out:
#            Name           Age Monthly_Salary
# 0  Not Eligible  Not Eligible   Not Eligible
# 1  Not Eligible  Not Eligible   Not Eligible
# 2        Lalita            18          50000
# 3  Not Eligible  Not Eligible   Not Eligible

# %%
# Rows and Columns - Operations(Add , Update , Delete) # Bookmark 34 minutes

# %%
df
# Out:
#        Name  Age  Monthly_Salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000
# 2    Lalita   18           50000
# 3   Rishabh   19           30000

# %%
# add new column 1
df['Team'] = ['CEO' , 'HR' , 'CTO' , 'DA']
df
# Out:
#        Name  Age  Monthly_Salary Team
# 0    Madhav   16           90000  CEO
# 1  Vishakha   17           70000   HR
# 2    Lalita   18           50000  CTO
# 3   Rishabh   19           30000   DA

# %%
df['Bonus'] = df['Monthly_Salary'] * 2
df
# Out:
#        Name  Age  Monthly_Salary Team   Bonus
# 0    Madhav   16           90000  CEO  180000
# 1  Vishakha   17           70000   HR  140000
# 2    Lalita   18           50000  CTO  100000
# 3   Rishabh   19           30000   DA   60000

# %%
# add new row
df.loc[len(df)] = ['ABC' , 21 , 21000 , 'IT' , 2000]
df
# Out:
#        Name  Age  Monthly_Salary Team   Bonus
# 0    Madhav   16           90000  CEO  180000
# 1  Vishakha   17           70000   HR  140000
# 2    Lalita   18           50000  CTO  100000
# 3   Rishabh   19           30000   DA   60000
# 4       ABC   21           21000   IT    2000

# %%
len(df)
# Out:
# 5

# %%
# update value using index name
df.loc[0 , "Monthly_Salary"] = 95000
df
# Out:
#        Name  Age  Monthly_Salary Team   Bonus
# 0    Madhav   16           95000  CEO  180000
# 1  Vishakha   17           70000   HR  140000
# 2    Lalita   18           50000  CTO  100000
# 3   Rishabh   19           30000   DA   60000
# 4       ABC   21           21000   IT    2000

# %%
# Update value using column name
df.loc[df.Name == "Madhav" , 'Monthly_Salary']  = 91000
df
# Out:
#        Name  Age  Monthly_Salary Team   Bonus
# 0    Madhav   16           91000  CEO  180000
# 1  Vishakha   17           70000   HR  140000
# 2    Lalita   18           50000  CTO  100000
# 3   Rishabh   19           30000   DA   60000
# 4       ABC   21           21000   IT    2000

# %%
# Delete value - row and column values , 0 means row , 1 means columns

# %%
df.drop(df[df.Name == 'ABC'].index , inplace = True) # drop row , axis = 0

# %%
# df.drop("Madhav" , inplace = True)

# %%
df
# Out:
#        Name  Age  Monthly_Salary Team   Bonus
# 0    Madhav   16           91000  CEO  180000
# 1  Vishakha   17           70000   HR  140000
# 2    Lalita   18           50000  CTO  100000
# 3   Rishabh   19           30000   DA   60000

# %%
df[df.Name == 'ABC']
# Out:
# Empty DataFrame
# Columns: [Name, Age, Monthly_Salary, Team, Bonus]
# Index: []

# %%
df.drop('Bonus' , axis = 1 , inplace = True) # 1 = columns

# %%
df
# Out:
#        Name  Age  Monthly_Salary Team
# 0    Madhav   16           91000  CEO
# 1  Vishakha   17           70000   HR
# 2    Lalita   18           50000  CTO
# 3   Rishabh   19           30000   DA

# %%
# df.drop(['Bonus' , 'Team'] , axis = 1] # 1 means columns

# %%
df
# Out:
#        Name  Age  Monthly_Salary Team
# 0    Madhav   16           91000  CEO
# 1  Vishakha   17           70000   HR
# 2    Lalita   18           50000  CTO
# 3   Rishabh   19           30000   DA

# %%
df.drop(1 , axis = 0)
# Out:
#       Name  Age  Monthly_Salary Team
# 0   Madhav   16           91000  CEO
# 2   Lalita   18           50000  CTO
# 3  Rishabh   19           30000   DA

# %%
# sort values in ascentding , descentding
df.sort_values('Monthly_Salary' , inplace = True)

# %%
df.sort_values('Age' , inplace = True)

# %%
df
# Out:
#        Name  Age  Monthly_Salary Team
# 0    Madhav   16           91000  CEO
# 1  Vishakha   17           70000   HR
# 2    Lalita   18           50000  CTO
# 3   Rishabh   19           30000   DA

# %%
# 7 woring with data values

# %%
df
# Out:
#        Name  Age  Monthly_Salary Team
# 0    Madhav   16           91000  CEO
# 1  Vishakha   17           70000   HR
# 2    Lalita   18           50000  CTO
# 3   Rishabh   19           30000   DA

# %%
df['DOJ'] = ['2024-01-01', '2024-01-15', '2024-03-28', '2024-03-03']

# %%
df
# Out:
#        Name  Age  Monthly_Salary Team         DOJ
# 0    Madhav   16           91000  CEO  2024-01-01
# 1  Vishakha   17           70000   HR  2024-01-15
# 2    Lalita   18           50000  CTO  2024-03-28
# 3   Rishabh   19           30000   DA  2024-03-03

# %%
df['DOJ'].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df['DOJ'] = pd.to_datetime(df['DOJ'])

# %%
df['DOJ'].dtype
# Out:
# dtype('<M8[us]')

# %%
df
# Out:
#        Name  Age  Monthly_Salary Team        DOJ
# 0    Madhav   16           91000  CEO 2024-01-01
# 1  Vishakha   17           70000   HR 2024-01-15
# 2    Lalita   18           50000  CTO 2024-03-28
# 3   Rishabh   19           30000   DA 2024-03-03

# %%
df1 = df

# %%
df1
# Out:
#        Name  Age  Monthly_Salary Team        DOJ
# 0    Madhav   16           91000  CEO 2024-01-01
# 1  Vishakha   17           70000   HR 2024-01-15
# 2    Lalita   18           50000  CTO 2024-03-28
# 3   Rishabh   19           30000   DA 2024-03-03

# %%
df1['DOJ2'] = ['01-01-2025', '15-01-2025', '28-03-2025', '03-03-2025']

# %%
df1['DOJ'] = ['2024-01-01', '2024-01-15', '2024-03-28', '2024-03-03']

# %%
df1['DOJ2'].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df1['DOJ2'] = pd.to_datetime(df1['DOJ2'] , format = '%d-%m-%Y') # Y means full year

# %%
df1['DOJ2'].dtype
# Out:
# dtype('<M8[us]')

# %%
# df = df.drop('DOJ2' , axis  = 1)

# %%
df
# Out:
#        Name  Age  Monthly_Salary Team         DOJ       DOJ2
# 0    Madhav   16           91000  CEO  2024-01-01 2025-01-01
# 1  Vishakha   17           70000   HR  2024-01-15 2025-01-15
# 2    Lalita   18           50000  CTO  2024-03-28 2025-03-28
# 3   Rishabh   19           30000   DA  2024-03-03 2025-03-03

# %%
df
# Out:
#        Name  Age  Monthly_Salary Team         DOJ       DOJ2
# 0    Madhav   16           91000  CEO  2024-01-01 2025-01-01
# 1  Vishakha   17           70000   HR  2024-01-15 2025-01-15
# 2    Lalita   18           50000  CTO  2024-03-28 2025-03-28
# 3   Rishabh   19           30000   DA  2024-03-03 2025-03-03

# %%
df = df.drop('DOJ2' , axis = 1)
df
# Out:
#        Name  Age  Monthly_Salary Team         DOJ
# 0    Madhav   16           91000  CEO  2024-01-01
# 1  Vishakha   17           70000   HR  2024-01-15
# 2    Lalita   18           50000  CTO  2024-03-28
# 3   Rishabh   19           30000   DA  2024-03-03

# %%
df['DOJ'] = pd.to_datetime(df['DOJ'])

# %%
df['DOJ'].dtype
# Out:
# dtype('<M8[us]')

# %%
df['DOJ'].dt.month
df['DOJ'].dt.day
df['DOJ'].dt.day_name()
# Out:
# 0      Monday
# 1      Monday
# 2    Thursday
# 3      Sunday
# Name: DOJ, dtype: str

# %%
df['Month'] = df['DOJ'].dt.month

# %%
df
# Out:
#        Name  Age  Monthly_Salary Team        DOJ  Month
# 0    Madhav   16           91000  CEO 2024-01-01      1
# 1  Vishakha   17           70000   HR 2024-01-15      1
# 2    Lalita   18           50000  CTO 2024-03-28      3
# 3   Rishabh   19           30000   DA 2024-03-03      3

# %%
df['DOJ'] + pd.Timedelta(days = 90)
# Out:
# 0   2024-03-31
# 1   2024-04-14
# 2   2024-06-26
# 3   2024-06-01
# Name: DOJ, dtype: datetime64[us]

# %%
# 8. Handling Missing Values

# %%
df
# Out:
#        Name  Age  Monthly_Salary Team        DOJ  Month
# 0    Madhav   16           91000  CEO 2024-01-01      1
# 1  Vishakha   17           70000   HR 2024-01-15      1
# 2    Lalita   18           50000  CTO 2024-03-28      3
# 3   Rishabh   19           30000   DA 2024-03-03      3

# %%
df.isnull()
# Out:
#     Name    Age  Monthly_Salary   Team    DOJ  Month
# 0  False  False           False  False  False  False
# 1  False  False           False  False  False  False
# 2  False  False           False  False  False  False
# 3  False  False           False  False  False  False

# %%
import numpy as np

# %%
df.loc[df.Name == 'Rishabh' , 'Salary'] = np.nan

# %%
df.rename(columns={'Monthly_Salary': 'Salary'}, inplace=True)

# %%
df
# Out:
#        Name  Age  Salary Team         DOJ       DOJ2  Salary
# 0    Madhav   16   91000  CEO  2024-01-01 2025-01-01     NaN
# 1  Vishakha   17   70000   HR  2024-01-15 2025-01-15     NaN
# 2    Lalita   18   50000  CTO  2024-03-28 2025-03-28     NaN
# 3   Rishabh   19   30000   DA  2024-03-03 2025-03-03     NaN

# %%
df
# Out:
#        Name  Age  Salary Team         DOJ       DOJ2  Salary
# 0    Madhav   16   91000  CEO  2024-01-01 2025-01-01     NaN
# 1  Vishakha   17   70000   HR  2024-01-15 2025-01-15     NaN
# 2    Lalita   18   50000  CTO  2024-03-28 2025-03-28     NaN
# 3   Rishabh   19   30000   DA  2024-03-03 2025-03-03     NaN

# %%
df.drop('DOJ2' , axis = 1 , inplace = True)

# %%
df.drop(Salary
# Out:
#        Name  Age  Salary Team         DOJ  Salary
# 0    Madhav   16   91000  CEO  2024-01-01     NaN
# 1  Vishakha   17   70000   HR  2024-01-15     NaN
# 2    Lalita   18   50000  CTO  2024-03-28     NaN
# 3   Rishabh   19   30000   DA  2024-03-03     NaN

# %%
df = df.loc[:, ~df.columns.duplicated(keep='first')]
df
# Out:
#        Name  Age  Salary Team         DOJ
# 0    Madhav   16   91000  CEO  2024-01-01
# 1  Vishakha   17   70000   HR  2024-01-15
# 2    Lalita   18   50000  CTO  2024-03-28
# 3   Rishabh   19   30000   DA  2024-03-03

# %%
df.loc[df.Name == 'Rishabh' , 'Salary'] = np.nan

# %%
df
# Out:
#        Name  Age   Salary Team         DOJ
# 0    Madhav   16  91000.0  CEO  2024-01-01
# 1  Vishakha   17  70000.0   HR  2024-01-15
# 2    Lalita   18  50000.0  CTO  2024-03-28
# 3   Rishabh   19      NaN   DA  2024-03-03

# %%
df.isnull().sum()
# Out:
# Name      0
# Age       0
# Salary    1
# Team      0
# DOJ       0
# dtype: int64

# %%
df = df.fillna(0)

# %%
df
# Out:
#        Name  Age   Salary Team         DOJ
# 0    Madhav   16  91000.0  CEO  2024-01-01
# 1  Vishakha   17  70000.0   HR  2024-01-15
# 2    Lalita   18  50000.0  CTO  2024-03-28
# 3   Rishabh   19      0.0   DA  2024-03-03

# %%
df.loc[df.Name == 'Rishabh', 'Salary'] = 30000

# %%
df = df.drop('Rishabh')

# %%
df
# Out:
#        Name   Age   Salary Team         DOJ
# 0    Madhav  16.0  91000.0  CEO  2024-01-01
# 1  Vishakha  17.0  70000.0   HR  2024-01-15
# 2    Lalita  18.0  50000.0  CTO  2024-03-28
# 3   Rishabh  19.0  30000.0   DA  2024-03-03

# %%
# 9
import dill
# पूरी नोटबुक का स्टेट 'notebook_env.db' फाइल में सेव करें
dill.dump_session('notebook_env.db')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[143], line 2
#       1 # 9
# ----> 2 import dill
#       3 # पूरी नोटबुक का स्टेट 'notebook_env.db' फाइल में सेव करें
#       4 dill.dump_session('notebook_env.db')
#
# ModuleNotFoundError: No module named 'dill'

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
import dill
# सेव किया हुआ स्टेट वापस लोड करें
dill.load_session('notebook_env.db')

# %%
df
# Out:
#        Name   Age   Salary Team         DOJ
# 0    Madhav  16.0  91000.0  CEO  2024-01-01
# 1  Vishakha  17.0  70000.0   HR  2024-01-15
# 2    Lalita  18.0  50000.0  CTO  2024-03-28
# 3   Rishabh  19.0  30000.0   DA  2024-03-03

# %%
df['DOJ'].dtype
# Out:
# dtype('<M8[us]')

# %%
df['DOJ']= pd.to_datetime(df['DOJ'])

# %%
df['Month'] = df['DOJ'].dt.month

# %%
df
# Out:
#        Name   Age   Salary Team        DOJ  Month
# 0    Madhav  16.0  91000.0  CEO 2024-01-01      1
# 1  Vishakha  17.0  70000.0   HR 2024-01-15      1
# 2    Lalita  18.0  50000.0  CTO 2024-03-28      3
# 3   Rishabh  19.0  30000.0   DA 2024-03-03      3

# %%
df['Month'].value_counts()
# Out:
# Month
# 1    2
# 3    2
# Name: count, dtype: int64

# %%
df[df['Month'] == 1].value_counts()
# Out:
# Name      Age   Salary   Team  DOJ         Month
# Madhav    16.0  91000.0  CEO   2024-01-01  1        1
# Vishakha  17.0  70000.0  HR    2024-01-15  1        1
# Name: count, dtype: int64

# %%
df.groupby('Month')['Salary'].mean()
# Out:
# Month
# 1    80500.0
# 3    40000.0
# Name: Salary, dtype: float64

# %%
df.groupby('Month').agg({'Salary':'mean' , 'Name':'count'})
# Out:
#         Salary  Name
# Month
# 1      80500.0     2
# 3      40000.0     2

# %%
# 10  Concatenate(copy paste) and merge

# %%
df1 = pd.DataFrame({'ID' : [1,2,3] , 'Name' : ['A','B','C']})
df1
# Out:
#    ID Name
# 0   1    A
# 1   2    B
# 2   3    C

# %%
df2 = pd.DataFrame({'ID' : [1,2,2,4] , 'Score' : [88,96,77,79]})
df2
# Out:
#    ID  Score
# 0   1     88
# 1   2     96
# 2   2     77
# 3   4     79

# %%
pd.concat([df1,df2] , axis = 0) # vertical / row level / top on top
pd.concat([df1,df2] , axis = 1) # Horizantal/ column level / side on side
# Out:
#     ID Name  ID  Score
# 0  1.0    A   1     88
# 1  2.0    B   2     96
# 2  3.0    C   2     77
# 3  NaN  NaN   4     79

# %%
# merge = join
pd.merge(df1 , df2 , how = 'inner' , on = 'ID')
# Out:
#    ID Name  Score
# 0   1    A     88
# 1   2    B     96
# 2   2    B     77

# %%
pd.merge(df1 , df2 , how = 'inner' , left_on = 'ID' , right_on = 'ID')
# Out:
#    ID Name  Score
# 0   1    A     88
# 1   2    B     96
# 2   2    B     77

# %%
# AI AND CHATGPT
