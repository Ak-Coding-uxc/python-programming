# %%
import pandas as pd

# %%
 df = pd.DataFrame([11,221,34] , columns = ['Numbers'])

# %%
df
# Out:
#    Numbers
# 0       11
# 1      221
# 2       34

# %%
df[(df['Numbers'] == 34)]
# Out:
#    Numbers
# 2       34

# %%
print(type(df))
# Out:
# <class 'pandas.DataFrame'>

# %%
data = {
    'Name': ['Madhav', 'Vishakha', 'Lalita', 'Rishabh'],
    'Age': [16,17,18,19],
    'Salary': [90000, 70000, 50000, 30000]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#        Name  Age  Salary
# 0    Madhav   16   90000
# 1  Vishakha   17   70000
# 2    Lalita   18   50000
# 3   Rishabh   19   30000

# %%
df[df['Name'] == 'Lalita'].Salary
# Out:
# 2    50000
# Name: Salary, dtype: int64

# %%
df.shape
# Out:
# (4, 3)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Salary'], dtype='str')

# %%
df.rename(columns = {'Salary' : 'Monthly_Salary'} , inplace = True)

# %%
df
# Out:
#        Name  Age  Monthly_Salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000
# 2    Lalita   18           50000
# 3   Rishabh   19           30000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            4 non-null      str
#  1   Age             4 non-null      int64
#  2   Monthly_Salary  4 non-null      int64
# dtypes: int64(2), str(1)
# memory usage: 228.0 bytes

# %%
df.describe()
# Out:
#              Age  Monthly_Salary
# count   4.000000        4.000000
# mean   17.500000    60000.000000
# std     1.290994    25819.888975
# min    16.000000    30000.000000
# 25%    16.750000    45000.000000
# 50%    17.500000    60000.000000
# 75%    18.250000    75000.000000
# max    19.000000    90000.000000

# %%
df.to_csv(r'C:\Users\amank\Desktop\sem\Practice_Result.csv' , index = False)

# %%
df.rename( columns = { 'Character Name'  : 'Name'} , inplace = True)

# %%
df
# Out:
#        Name  Age  Monthly_Salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000
# 2    Lalita   18           50000
# 3   Rishabh   19           30000

# %%
df1 = pd.read_csv(r"C:\Users\amank\Desktop\sem\Practice_Result.csv")

# %%
df1
# Out:
#        Name  Age  Monthly_Salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000
# 2    Lalita   18           50000
# 3   Rishabh   19           30000

# %%
df['Name']
# Out:
# 0      Madhav
# 1    Vishakha
# 2      Lalita
# 3     Rishabh
# Name: Name, dtype: str

# %%
df[['Name']] # select sinlge column
# Out:
#        Name
# 0    Madhav
# 1  Vishakha
# 2    Lalita
# 3   Rishabh

# %%
df[['Name' , 'Monthly_Salary']]
# Out:
#        Name  Monthly_Salary
# 0    Madhav           90000
# 1  Vishakha           70000
# 2    Lalita           50000
# 3   Rishabh           30000

# %%
df.loc[df.Name == 'Madhav']
# Out:
#      Name  Age  Monthly_Salary
# 0  Madhav   16           90000

# %%
df[df['Name'] == 'Madhav']
# Out:
#      Name  Age  Monthly_Salary
# 0  Madhav   16           90000

# %%
df.loc[(df.Name == "Madhav") & (df.Age == 16)]
# Out:
#      Name  Age  Monthly_Salary
# 0  Madhav   16           90000

# %%
df.loc[0:2]
# Out:
#        Name  Age  Monthly_Salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000
# 2    Lalita   18           50000

# %%
df.iloc[0:2]
# Out:
#        Name  Age  Monthly_Salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000

# %%
df.loc[(df.Name == "Madhav") & (df.Age >= 10)]
# Out:
#      Name  Age  Monthly_Salary
# 0  Madhav   16           90000

# %%
# Filter  Values

# %%
df
# Out:
#        Name  Age  Monthly_Salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000
# 2    Lalita   18           50000
# 3   Rishabh   19           30000

# %%
df.rename(columns = {'Monthly_Salary': 'Salary'}, inplace = True)

# %%
df
# Out:
#        Name  Age  Salary
# 0    Madhav   16   90000
# 1  Vishakha   17   70000
# 2    Lalita   18   50000
# 3   Rishabh   19   30000

# %%
df_age_filter = df[df['Age'] >= 18]

# %%
df_age_filter
# Out:
#       Name  Age  Salary
# 2   Lalita   18   50000
# 3  Rishabh   19   30000

# %%
df[(df['Age'] >= 18) & (df['Salary'] >= 45000)]
# Out:
#      Name  Age  Salary
# 2  Lalita   18   50000

# %%
df.where((df.Age >= 18) & (df.Salary >= 45000) , other = '-')
# Out:
#      Name Age Salary
# 0       -   -      -
# 1       -   -      -
# 2  Lalita  18  50000
# 3       -   -      -

# %%
df
# Out:
#        Name  Age  Salary
# 0    Madhav   16   90000
# 1  Vishakha   17   70000
# 2    Lalita   18   50000
# 3   Rishabh   19   30000

# %%
df
# Out:
#        Name  Age  Salary
# 0    Madhav   16   90000
# 1  Vishakha   17   70000
# 2    Lalita   18   50000
# 3   Rishabh   19   30000

# %%
df['Team'] = [ 1 , 2, 3 , 4]

# %%
df
# Out:
#        Name  Age  Salary  Team
# 0    Madhav   16   90000     1
# 1  Vishakha   17   70000     2
# 2    Lalita   18   50000     3
# 3   Rishabh   19   30000     4

# %%
df['Bonus'] = df['Salary'] * 4

# %%
df
# Out:
#        Name  Age  Salary  Team   Bonus
# 0    Madhav   16   90000     1  360000
# 1  Vishakha   17   70000     2  280000
# 2    Lalita   18   50000     3  200000
# 3   Rishabh   19   30000     4  120000

# %%
df.loc[len(df)] = [ "Raju" , 2 , 4 , 'Dholokpur' , 8]

# %%
df
# Out:
#        Name  Age  Salary       Team   Bonus
# 0    Madhav   16   90000          1  360000
# 1  Vishakha   17   70000          2  280000
# 2    Lalita   18   50000          3  200000
# 3   Rishabh   19   30000          4  120000
# 4      Raju    2       4  Dholokpur       8

# %%
df.drop(df[df.Team == 5].index , axis = 0 ,  inplace = True)

# %%
df
# Out:
#        Name  Age  Salary       Team   Bonus
# 0    Madhav   16   90000          1  360000
# 1  Vishakha   17   70000          2  280000
# 2    Lalita   18   50000          3  200000
# 3   Rishabh   19   30000          4  120000
# 4      Raju    2       4  Dholokpur       8

# %%
df.loc[5, 'Team'] = 5

# %%
df
# Out:
#        Name   Age   Salary       Team     Bonus
# 0    Madhav  16.0  90000.0          1  360000.0
# 1  Vishakha  17.0  70000.0          2  280000.0
# 2    Lalita  18.0  50000.0          3  200000.0
# 3   Rishabh  19.0  30000.0          4  120000.0
# 4      Raju   2.0   9999.0  Dholokpur    9999.0
# 5       NaN   NaN      NaN          5       NaN

# %%
df.loc[df.Name == 'Raju' , 'Salary'] = 9999

# %%
df.loc[df.Name == 'Raju' , 'Bonus'] = df['Salary'] * 1

# %%
df = df.drop(df[df.Team == 5].index)

# %%
df
# Out:
#        Name   Age   Salary       Team     Bonus
# 0    Madhav  16.0  90000.0          1  360000.0
# 1  Vishakha  17.0  70000.0          2  280000.0
# 2    Lalita  18.0  50000.0          3  200000.0
# 3   Rishabh  19.0  30000.0          4  120000.0
# 4      Raju   2.0   9999.0  Dholokpur    9999.0

# %%
df.drop(1, axis=0)
# Out:
#       Name   Age   Salary       Team     Bonus
# 0   Madhav  16.0  90000.0          1  360000.0
# 2   Lalita  18.0  50000.0          3  200000.0
# 3  Rishabh  19.0  30000.0          4  120000.0
# 4     Raju   2.0   9999.0  Dholokpur    9999.0

# %%
df.drop('Bonus', axis = 1, inplace = True)

# %%
df
# Out:
#        Name   Age   Salary       Team
# 0    Madhav  16.0  90000.0          1
# 1  Vishakha  17.0  70000.0          2
# 2    Lalita  18.0  50000.0          3
# 3   Rishabh  19.0  30000.0          4
# 4      Raju   2.0   9999.0  Dholokpur

# %%
df.drop(4,axis = 0)
# Out:
#        Name   Age   Salary Team
# 0    Madhav  16.0  90000.0    1
# 1  Vishakha  17.0  70000.0    2
# 2    Lalita  18.0  50000.0    3
# 3   Rishabh  19.0  30000.0    4

# %%
df.loc[len(df)] = ['Ak' , 20 , 89000, 6] # input

# %%
df =df.drop(5, axis = 0)

# %%
df = df.drop(4, axis = 0)

# %%
df
# Out:
#        Name   Age   Salary Team
# 0    Madhav  16.0  90000.0    1
# 1  Vishakha  17.0  70000.0    2
# 2    Lalita  18.0  50000.0    3
# 3   Rishabh  19.0  30000.0    4

# %%
df.sort_values('Salary' , ascending = False)
# Out:
#        Name   Age   Salary Team
# 0    Madhav  16.0  90000.0    1
# 1  Vishakha  17.0  70000.0    2
# 2    Lalita  18.0  50000.0    3
# 3   Rishabh  19.0  30000.0    4

# %%
df.loc[len(df)] = ['Ak' ,20 , 10000000 , 5]

# %%
df
# Out:
#        Name   Age      Salary Team
# 0    Madhav  16.0     90000.0    1
# 1  Vishakha  17.0     70000.0    2
# 2    Lalita  18.0     50000.0    3
# 3   Rishabh  19.0     30000.0    4
# 4        Ak  20.0  10000000.0    5

# %%
df.sort_values('Salary' , ascending = False)
# Out:
#        Name   Age      Salary Team
# 4        Ak  20.0  10000000.0    5
# 0    Madhav  16.0     90000.0    1
# 1  Vishakha  17.0     70000.0    2
# 2    Lalita  18.0     50000.0    3
# 3   Rishabh  19.0     30000.0    4

# %%
df = df.drop(df[df.Name == 'Ak'].index)

# %%
df['DOJ'] = ['2024-01-01', '2024-01-15', '2024-03-28', '2024-03-03']
df
# Out:
#        Name   Age   Salary Team         DOJ
# 0    Madhav  16.0  90000.0    1  2024-01-01
# 1  Vishakha  17.0  70000.0    2  2024-01-15
# 2    Lalita  18.0  50000.0    3  2024-03-28
# 3   Rishabh  19.0  30000.0    4  2024-03-03

# %%
df
# Out:
#        Name   Age   Salary Team         DOJ
# 0    Madhav  16.0  90000.0    1  2024-01-01
# 1  Vishakha  17.0  70000.0    2  2024-01-15
# 2    Lalita  18.0  50000.0    3  2024-03-28
# 3   Rishabh  19.0  30000.0    4  2024-03-03

# %%
df['DOJ'].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df['DOJ'] = pd.to_datetime(df['DOJ'])

# %%
df
# Out:
#        Name   Age   Salary Team        DOJ
# 0    Madhav  16.0  90000.0    1 2024-01-01
# 1  Vishakha  17.0  70000.0    2 2024-01-15
# 2    Lalita  18.0  50000.0    3 2024-03-28
# 3   Rishabh  19.0  30000.0    4 2024-03-03

# %%
df['DOJ'].dtype
# Out:
# dtype('<M8[us]')

# %%
df['DOJ2'] = [ '01-01-2025', '15-01-2025', '28-03-2025', '03-03-2025']

# %%
df
# Out:
#        Name   Age   Salary Team        DOJ        DOJ2
# 0    Madhav  16.0  90000.0    1 2024-01-01  01-01-2025
# 1  Vishakha  17.0  70000.0    2 2024-01-15  15-01-2025
# 2    Lalita  18.0  50000.0    3 2024-03-28  28-03-2025
# 3   Rishabh  19.0  30000.0    4 2024-03-03  03-03-2025

# %%
df['DOJ2'].dtype
# Out:
# dtype('<M8[us]')

# %%
df['DOJ2'] = pd.to_datetime(df['DOJ2'] , format = '%d-%m-%Y')

# %%
df1 = df

# %%
df1
# Out:
#        Name   Age   Salary Team        DOJ       DOJ2
# 0    Madhav  16.0  90000.0    1 2024-01-01 2025-01-01
# 1  Vishakha  17.0  70000.0    2 2024-01-15 2025-01-15
# 2    Lalita  18.0  50000.0    3 2024-03-28 2025-03-28
# 3   Rishabh  19.0  30000.0    4 2024-03-03 2025-03-03

# %%
df.loc[0,'DOJ2'] = '2033-03-03'

# %%
df
# Out:
#        Name   Age   Salary Team        DOJ       DOJ2
# 0    Madhav  16.0  90000.0    1 2024-01-01 2033-03-03
# 1  Vishakha  17.0  70000.0    2 2024-01-15 2025-01-15
# 2    Lalita  18.0  50000.0    3 2024-03-28 2025-03-28
# 3   Rishabh  19.0  30000.0    4 2024-03-03 2025-03-03

# %%
df1
# Out:
#        Name   Age   Salary Team        DOJ       DOJ2
# 0    Madhav  16.0  90000.0    1 2024-01-01 2033-03-03
# 1  Vishakha  17.0  70000.0    2 2024-01-15 2025-01-15
# 2    Lalita  18.0  50000.0    3 2024-03-28 2025-03-28
# 3   Rishabh  19.0  30000.0    4 2024-03-03 2025-03-03

# %%
df2 = df.copy()

# %%
df2
# Out:
#        Name   Age   Salary Team        DOJ       DOJ2
# 0    Madhav  16.0  90000.0    1 2024-01-01 2033-03-03
# 1  Vishakha  17.0  70000.0    2 2024-01-15 2025-01-15
# 2    Lalita  18.0  50000.0    3 2024-03-28 2025-03-28
# 3   Rishabh  19.0  30000.0    4 2024-03-03 2025-03-03

# %%
df.loc[1,'DOJ2'] = '2044-04-22'

# %%
df
# Out:
#        Name   Age   Salary Team        DOJ       DOJ2
# 0    Madhav  16.0  90000.0    1 2024-01-01 2033-03-03
# 1  Vishakha  17.0  70000.0    2 2024-01-15 2044-04-22
# 2    Lalita  18.0  50000.0    3 2024-03-28 2025-03-28
# 3   Rishabh  19.0  30000.0    4 2024-03-03 2025-03-03

# %%
df1
# Out:
#        Name   Age   Salary Team        DOJ       DOJ2
# 0    Madhav  16.0  90000.0    1 2024-01-01 2033-03-03
# 1  Vishakha  17.0  70000.0    2 2024-01-15 2044-04-22
# 2    Lalita  18.0  50000.0    3 2024-03-28 2025-03-28
# 3   Rishabh  19.0  30000.0    4 2024-03-03 2025-03-03

# %%
df2
# Out:
#        Name   Age   Salary Team        DOJ       DOJ2
# 0    Madhav  16.0  90000.0    1 2024-01-01 2033-03-03
# 1  Vishakha  17.0  70000.0    2 2024-01-15 2025-01-15
# 2    Lalita  18.0  50000.0    3 2024-03-28 2025-03-28
# 3   Rishabh  19.0  30000.0    4 2024-03-03 2025-03-03

# %%
df
# Out:
#        Name   Age   Salary Team        DOJ       DOJ2
# 0    Madhav  16.0  90000.0    1 2024-01-01 2033-03-03
# 1  Vishakha  17.0  70000.0    2 2024-01-15 2044-04-22
# 2    Lalita  18.0  50000.0    3 2024-03-28 2025-03-28
# 3   Rishabh  19.0  30000.0    4 2024-03-03 2025-03-03

# %%
df.drop('DOJ2' ,axis = 1 , inplace = True)

# %%
df
# Out:
#        Name   Age   Salary Team        DOJ
# 0    Madhav  16.0  90000.0    1 2024-01-01
# 1  Vishakha  17.0  70000.0    2 2024-01-15
# 2    Lalita  18.0  50000.0    3 2024-03-28
# 3   Rishabh  19.0  30000.0    4 2024-03-03

# %%
df['Month']  = df['DOJ'].dt.month

# %%
df
# Out:
#        Name   Age   Salary Team        DOJ  Month
# 0    Madhav  16.0  90000.0    1 2024-01-01      1
# 1  Vishakha  17.0  70000.0    2 2024-01-15      1
# 2    Lalita  18.0  50000.0    3 2024-03-28      3
# 3   Rishabh  19.0  30000.0    4 2024-03-03      3

# %%
df['Retirement date'] = df['DOJ'] + pd.Timedelta(weeks = 1565)

# %%
df
# Out:
#        Name   Age   Salary Team        DOJ  Month Retirement date
# 0    Madhav  16.0  90000.0    1 2024-01-01      1      2053-12-29
# 1  Vishakha  17.0  70000.0    2 2024-01-15      1      2054-01-12
# 2    Lalita  18.0  50000.0    3 2024-03-28      3      2054-03-26
# 3   Rishabh  19.0  30000.0    4 2024-03-03      3      2054-03-01

# %%
df.drop('Month' , axis = 1 , inplace = True)

# %%
df
# Out:
#        Name   Age   Salary Team        DOJ Retirement date
# 0    Madhav  16.0  90000.0    1 2024-01-01      2053-12-29
# 1  Vishakha  17.0  70000.0    2 2024-01-15      2054-01-12
# 2    Lalita  18.0  50000.0    3 2024-03-28      2054-03-26
# 3   Rishabh  19.0  30000.0    4 2024-03-03      2054-03-01

# %%
df
# Out:
#        Name   Age   Salary Team        DOJ Retirement date
# 0    Madhav  16.0  90000.0    1 2024-01-01      2053-12-29
# 1  Vishakha  17.0  70000.0    2 2024-01-15      2054-01-12
# 2    Lalita  18.0  50000.0    3 2024-03-28      2054-03-26
# 3   Rishabh  19.0  30000.0    4 2024-03-03      2054-03-01

# %%
import numpy as np

# %%
df.loc[df.Name == 'Madhav' , 'Salary'] = 67
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[167], line 1
# ----> 1 df.loc[df.Name == 'Madhav' , 'Salary'] = 67
#
# AttributeError: 'float' object has no attribute 'loc'

# %%
df1
# Out:
#        Name   Age   Salary Team        DOJ Retirement date
# 0    Madhav  16.0      NaN    1 2024-01-01      2053-12-29
# 1  Vishakha  17.0  70000.0    2 2024-01-15      2054-01-12
# 2    Lalita  18.0  50000.0    3 2024-03-28      2054-03-26
# 3   Rishabh  19.0  30000.0    4 2024-03-03      2054-03-01

# %%
df
# Out:
# nan

# %%
df1
# Out:
#        Name   Age   Salary Team        DOJ Retirement date
# 0    Madhav  16.0      NaN    1 2024-01-01      2053-12-29
# 1  Vishakha  17.0  70000.0    2 2024-01-15      2054-01-12
# 2    Lalita  18.0  50000.0    3 2024-03-28      2054-03-26
# 3   Rishabh  19.0  30000.0    4 2024-03-03      2054-03-01

# %%
df = df1

# %%
df
# Out:
#        Name   Age   Salary Team        DOJ Retirement date
# 0    Madhav  16.0      NaN    1 2024-01-01      2053-12-29
# 1  Vishakha  17.0  70000.0    2 2024-01-15      2054-01-12
# 2    Lalita  18.0  50000.0    3 2024-03-28      2054-03-26
# 3   Rishabh  19.0  30000.0    4 2024-03-03      2054-03-01

# %%
df.isnull()
# Out:
#     Name    Age  Salary   Team    DOJ  Retirement date
# 0  False  False    True  False  False            False
# 1  False  False   False  False  False            False
# 2  False  False   False  False  False            False
# 3  False  False   False  False  False            False

# %%
df[df.isnull()]
# Out:
#   Name  Age  Salary Team DOJ Retirement date
# 0  NaN  NaN     NaN  NaN NaT             NaT
# 1  NaN  NaN     NaN  NaN NaT             NaT
# 2  NaN  NaN     NaN  NaN NaT             NaT
# 3  NaN  NaN     NaN  NaN NaT             NaT

# %%
df
# Out:
#        Name   Age   Salary Team        DOJ Retirement date
# 0    Madhav  16.0      NaN    1 2024-01-01      2053-12-29
# 1  Vishakha  17.0  70000.0    2 2024-01-15      2054-01-12
# 2    Lalita  18.0  50000.0    3 2024-03-28      2054-03-26
# 3   Rishabh  19.0  30000.0    4 2024-03-03      2054-03-01

# %%
df.to_csv('Save Data.csv')

# %%
df
# Out:
#        Name   Age   Salary Team        DOJ Retirement date
# 0    Madhav  16.0      NaN    1 2024-01-01      2053-12-29
# 1  Vishakha  17.0  70000.0    2 2024-01-15      2054-01-12
# 2    Lalita  18.0  50000.0    3 2024-03-28      2054-03-26
# 3   Rishabh  19.0  30000.0    4 2024-03-03      2054-03-01

# %%
df.isnull().sum()
# Out:
# Name               0
# Age                0
# Salary             1
# Team               0
# DOJ                0
# Retirement date    0
# dtype: int64

# %%
df.fillna(9)
# Out:
#        Name   Age   Salary Team        DOJ Retirement date
# 0    Madhav  16.0      9.0    1 2024-01-01      2053-12-29
# 1  Vishakha  17.0  70000.0    2 2024-01-15      2054-01-12
# 2    Lalita  18.0  50000.0    3 2024-03-28      2054-03-26
# 3   Rishabh  19.0  30000.0    4 2024-03-03      2054-03-01

# %%
df['Name'].value_count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[186], line 1
# ----> 1 df['Name'].value_count()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'value_count'
